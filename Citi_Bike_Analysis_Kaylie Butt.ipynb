# %% [markdown]
# # Citi Bike Data
# - https://www.citibikenyc.com/system-data
#
# This Jupyter notebook does the following (as of Monday, Feb. 17):
# 1. Imports .json data of Station Info (consider to be static)
# 2. Imports .json data of Station Status (may change frequently)
# 3. Imports .csv of Citi Bike trips
#
#
# - We'll use the Station Info/Status data to build a VeRoViz "nodes" dataframe.
# - We'll use the trips data to build a VeRoViz "assignments" dataframe.
#
# With the nodes and assignments dataframes, we can then generate Leaflet maps (static) and Cesium movies.
#
# ---

# %%
# We'll need these libraries
import numpy as np
import time
import pandas as pd

# %%
# These libraries will help us import JSON data:
import json
import urllib.request

# %%
# Go ahead and import VeRoViz
import veroviz as vrv
vrv.checkVersion()
# Out:
# 'Your current installed version of veroviz is 0.3.1. You are up-to-date with the latest available version.'

# %%
# I like to use "environment" variables to store "private" stuff
# (like API keys, or paths to installed files).
# We'll need the `os` library for that:
import os

# See https://veroviz.org/documentation.html#installation for details

# %% [markdown]
# ---
#
# ## 1. Import Station Info (from .json)
# - These data are *mostly* static...certainly won't change throughout the course of a day.

# %%
# Here's one way to import JSON data.
# I'm leaving this here, because it will work with "GET" and "POST" requests,
# which we might use later this semester.
# Tim's approach (below) is a bit cleaner.
'''
import json
import urllib3

urllib3.disable_warnings()

http = urllib3.PoolManager()

response = http.request('GET', "https://gbfs.citibikenyc.com/gbfs/en/station_information.json")
station_info_data = json.loads(response.data.decode('utf-8'))
station_info_data
''';

# The trailing `;` keeps Jupyter from regurgitating our block comment

# %%
# Tim's approach for grabbing JSON data:
with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_information.json") as url:
    station_info_data = json.loads(url.read().decode())
#station_info_data

# %%
# station_info_data is a dictionary (which contains several sub-dictionaries).
# Get a list of keys within the station_info_data['data'] dictionary:
station_info_data['data'].keys()
# Out:
# dict_keys(['stations'])

# %%
# How many stations are there?
len(station_info_data['data']['stations'])
# Out:
# 935

# %%
# Convert the JSON data into a Pandas dataframe:
station_info_df = pd.DataFrame(station_info_data['data']['stations'])
station_info_df.head()
# Out:
#   station_id                           external_id                     name  \
# 0        304  66db6da2-0aca-11e7-82f6-3863bb44ef7c    Broadway & Battery Pl
# 1        359  66dbc982-0aca-11e7-82f6-3863bb44ef7c       E 47 St & Park Ave
# 2        367  66dbcdfc-0aca-11e7-82f6-3863bb44ef7c  E 53 St & Lexington Ave
# 3        402  66dbf0d0-0aca-11e7-82f6-3863bb44ef7c       Broadway & E 22 St
# 4       3443  66de8a86-0aca-11e7-82f6-3863bb44ef7c          W 52 St & 6 Ave
#
#   short_name        lat        lon  region_id     rental_methods  capacity  \
# 0    4962.01  40.704633 -74.013617         71  [CREDITCARD, KEY]        33
# 1    6584.12  40.755103 -73.974987         71  [CREDITCARD, KEY]        64
# 2    6617.09  40.758281 -73.970694         71  [CREDITCARD, KEY]        34
# 3    6098.07  40.740343 -73.989551         71  [CREDITCARD, KEY]        39
# 4    6740.01  40.761330 -73.979820         71  [CREDITCARD, KEY]        41
#
#                                           rental_url  \
# 0  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 1  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 2  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 3  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 4  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
#
#    electric_bike_surcharge_waiver  eightd_has_key_dispenser  \
# 0                           False                      True
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
#
#                              eightd_station_services  has_kiosk
# 0  [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'...       True
# 1  [{'id': '2e104e31-606a-44af-8b25-ceaffc338489'...       True
# 2  [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0'...       True
# 3  [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'...       True
# 4  [{'id': '286d75b2-088f-4a79-bf7d-223928be711c'...       True

# %%
station_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 14 columns):
# station_id                        935 non-null object
# external_id                       935 non-null object
# name                              935 non-null object
# short_name                        935 non-null object
# lat                               935 non-null float64
# lon                               935 non-null float64
# region_id                         935 non-null int64
# rental_methods                    935 non-null object
# capacity                          935 non-null int64
# rental_url                        935 non-null object
# electric_bike_surcharge_waiver    935 non-null bool
# eightd_has_key_dispenser          935 non-null bool
# eightd_station_services           6 non-null object
# has_kiosk                         935 non-null bool
# dtypes: bool(3), float64(2), int64(2), object(7)
# memory usage: 83.2+ KB

# %% [markdown]
# ---
#
# ## 2.  Get Station Status Data (from .json)
# - These data may change frequently.  I don't know how often they're updated.

# %%
# Using Murray's old approach:
'''
response = http.request('GET', "https://gbfs.citibikenyc.com/gbfs/en/station_status.json")
station_status_data = json.loads(response.data.decode('utf-8'))
station_status_data
''';

# %%
# Tim's approach for grabbing JSON data:
with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_status.json") as url:
    station_status_data = json.loads(url.read().decode())
station_status_data
# Out:
# {'last_updated': 1582813822,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '304',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813735,
#     'eightd_has_available_keys': True,
#     'eightd_active_station_services': [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'}]},
#    {'station_id': '359',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 41,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813593,
#     'eightd_has_available_keys': False,
#     'eightd_active_station_services': [{'id': '2e104e31-606a-44af-8b25-ceaffc338489'}]},
#    {'station_id': '367',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813748,
#     'eightd_has_available_keys': False,
#     'eightd_active_station_services': [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0'}]},
#    {'station_id': '402',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813797,
#     'eightd_has_available_keys': False,
#     'eightd_active_station_services': [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'}]},
#    {'station_id': '3443',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 34,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813759,
#     'eightd_has_available_keys': False,
#     'eightd_active_station_services': [{'id': '286d75b2-088f-4a79-bf7d-223928be711c'}]},
#    {'station_id': '72',
#     'num_bikes_available': 45,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813389,
#     'eightd_has_available_keys': False},
#    {'station_id': '79',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813501,
#     'eightd_has_available_keys': False},
#    {'station_id': '82',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813719,
#     'eightd_has_available_keys': False},
#    {'station_id': '83',
#     'num_bikes_available': 59,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813170,
#     'eightd_has_available_keys': False},
#    {'station_id': '116',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813815,
#     'eightd_has_available_keys': False},
#    {'station_id': '119',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813731,
#     'eightd_has_available_keys': False},
#    {'station_id': '120',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582811296,
#     'eightd_has_available_keys': False},
#    {'station_id': '127',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813804,
#     'eightd_has_available_keys': False},
#    {'station_id': '128',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813672,
#     'eightd_has_available_keys': False},
#    {'station_id': '143',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813399,
#     'eightd_has_available_keys': False},
#    {'station_id': '144',
#     'num_bikes_available': 56,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813253,
#     'eightd_has_available_keys': False},
#    {'station_id': '146',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 5,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813580,
#     'eightd_has_available_keys': False},
#    {'station_id': '150',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 40,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813282,
#     'eightd_has_available_keys': False},
#    {'station_id': '151',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813262,
#     'eightd_has_available_keys': True},
#    {'station_id': '157',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812047,
#     'eightd_has_available_keys': False},
#    {'station_id': '161',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813786,
#     'eightd_has_available_keys': False},
#    {'station_id': '164',
#     'num_bikes_available': 44,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813704,
#     'eightd_has_available_keys': False},
#    {'station_id': '167',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813604,
#     'eightd_has_available_keys': False},
#    {'station_id': '168',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813751,
#     'eightd_has_available_keys': False},
#    {'station_id': '173',
#     'num_bikes_available': 40,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813772,
#     'eightd_has_available_keys': False},
#    {'station_id': '174',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813632,
#     'eightd_has_available_keys': False},
#    {'station_id': '195',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813771,
#     'eightd_has_available_keys': False},
#    {'station_id': '212',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813804,
#     'eightd_has_available_keys': False},
#    {'station_id': '216',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582810943,
#     'eightd_has_available_keys': False},
#    {'station_id': '217',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813658,
#     'eightd_has_available_keys': True},
#    {'station_id': '223',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813770,
#     'eightd_has_available_keys': False},
#    {'station_id': '224',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813339,
#     'eightd_has_available_keys': True},
#    {'station_id': '228',
#     'num_bikes_available': 42,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813712,
#     'eightd_has_available_keys': False},
#    {'station_id': '229',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812988,
#     'eightd_has_available_keys': False},
#    {'station_id': '236',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 30,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813019,
#     'eightd_has_available_keys': False},
#    {'station_id': '237',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 33,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813508,
#     'eightd_has_available_keys': False},
#    {'station_id': '238',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813783,
#     'eightd_has_available_keys': False},
#    {'station_id': '239',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813788,
#     'eightd_has_available_keys': False},
#    {'station_id': '241',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813629,
#     'eightd_has_available_keys': False},
#    {'station_id': '242',
#     'num_bikes_available': 44,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813125,
#     'eightd_has_available_keys': False},
#    {'station_id': '244',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813255,
#     'eightd_has_available_keys': False},
#    {'station_id': '245',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813463,
#     'eightd_has_available_keys': True},
#    {'station_id': '247',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 53,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813618,
#     'eightd_has_available_keys': False},
#    {'station_id': '248',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813790,
#     'eightd_has_available_keys': False},
#    {'station_id': '249',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812422,
#     'eightd_has_available_keys': False},
#    {'station_id': '250',
#     'num_bikes_available': 40,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813299,
#     'eightd_has_available_keys': False},
#    {'station_id': '251',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813547,
#     'eightd_has_available_keys': False},
#    {'station_id': '252',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813435,
#     'eightd_has_available_keys': False},
#    {'station_id': '254',
#     'num_bikes_available': 42,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813742,
#     'eightd_has_available_keys': False},
#    {'station_id': '257',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813469,
#     'eightd_has_available_keys': False},
#    {'station_id': '258',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813801,
#     'eightd_has_available_keys': False},
#    {'station_id': '259',
#     'num_bikes_available': 39,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812860,
#     'eightd_has_available_keys': True},
#    {'station_id': '260',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813494,
#     'eightd_has_available_keys': False},
#    {'station_id': '261',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813346,
#     'eightd_has_available_keys': False},
#    {'station_id': '262',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813320,
#     'eightd_has_available_keys': False},
#    {'station_id': '264',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813730,
#     'eightd_has_available_keys': False},
#    {'station_id': '265',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813779,
#     'eightd_has_available_keys': False},
#    {'station_id': '267',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 68,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813814,
#     'eightd_has_available_keys': False},
#    {'station_id': '268',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813732,
#     'eightd_has_available_keys': False},
#    {'station_id': '270',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812870,
#     'eightd_has_available_keys': False},
#    {'station_id': '274',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813431,
#     'eightd_has_available_keys': False},
#    {'station_id': '275',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812869,
#     'eightd_has_available_keys': False},
#    {'station_id': '276',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813225,
#     'eightd_has_available_keys': False},
#    {'station_id': '278',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582809725,
#     'eightd_has_available_keys': False},
#    {'station_id': '280',
#     'num_bikes_available': 57,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813802,
#     'eightd_has_available_keys': False},
#    {'station_id': '281',
#     'num_bikes_available': 63,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813818,
#     'eightd_has_available_keys': False},
#    {'station_id': '282',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813581,
#     'eightd_has_available_keys': False},
#    {'station_id': '284',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813775,
#     'eightd_has_available_keys': False},
#    {'station_id': '285',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813778,
#     'eightd_has_available_keys': True},
#    {'station_id': '289',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813362,
#     'eightd_has_available_keys': False},
#    {'station_id': '291',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813017,
#     'eightd_has_available_keys': False},
#    {'station_id': '293',
#     'num_bikes_available': 48,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813779,
#     'eightd_has_available_keys': False},
#    {'station_id': '295',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813203,
#     'eightd_has_available_keys': False},
#    {'station_id': '297',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813679,
#     'eightd_has_available_keys': False},
#    {'station_id': '298',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813228,
#     'eightd_has_available_keys': False},
#    {'station_id': '301',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 44,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813697,
#     'eightd_has_available_keys': False},
#    {'station_id': '302',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813813,
#     'eightd_has_available_keys': False},
#    {'station_id': '303',
#     'num_bikes_available': 46,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813632,
#     'eightd_has_available_keys': False},
#    {'station_id': '305',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813593,
#     'eightd_has_available_keys': False},
#    {'station_id': '307',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813738,
#     'eightd_has_available_keys': False},
#    {'station_id': '308',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813681,
#     'eightd_has_available_keys': False},
#    {'station_id': '309',
#     'num_bikes_available': 40,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813302,
#     'eightd_has_available_keys': False},
#    {'station_id': '310',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813600,
#     'eightd_has_available_keys': False},
#    {'station_id': '311',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813704,
#     'eightd_has_available_keys': False},
#    {'station_id': '312',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813641,
#     'eightd_has_available_keys': False},
#    {'station_id': '313',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813370,
#     'eightd_has_available_keys': False},
#    {'station_id': '315',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813739,
#     'eightd_has_available_keys': True},
#    {'station_id': '316',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813585,
#     'eightd_has_available_keys': False},
#    {'station_id': '317',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 52,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813302,
#     'eightd_has_available_keys': False},
#    {'station_id': '319',
#     'num_bikes_available': 30,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813797,
#     'eightd_has_available_keys': False},
#    {'station_id': '320',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813658,
#     'eightd_has_available_keys': False},
#    {'station_id': '321',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813656,
#     'eightd_has_available_keys': True},
#    {'station_id': '323',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813594,
#     'eightd_has_available_keys': False},
#    {'station_id': '324',
#     'num_bikes_available': 51,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812516,
#     'eightd_has_available_keys': False},
#    {'station_id': '325',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813677,
#     'eightd_has_available_keys': False},
#    {'station_id': '326',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 34,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813535,
#     'eightd_has_available_keys': False},
#    {'station_id': '327',
#     'num_bikes_available': 35,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813784,
#     'eightd_has_available_keys': True},
#    {'station_id': '328',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813469,
#     'eightd_has_available_keys': False},
#    {'station_id': '330',
#     'num_bikes_available': 38,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813632,
#     'eightd_has_available_keys': False},
#    {'station_id': '331',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812969,
#     'eightd_has_available_keys': False},
#    {'station_id': '332',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 34,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812599,
#     'eightd_has_available_keys': False},
#    {'station_id': '334',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813618,
#     'eightd_has_available_keys': False},
#    {'station_id': '335',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813749,
#     'eightd_has_available_keys': False},
#    {'station_id': '336',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812958,
#     'eightd_has_available_keys': False},
#    {'station_id': '337',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813563,
#     'eightd_has_available_keys': False},
#    {'station_id': '339',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813609,
#     'eightd_has_available_keys': False},
#    {'station_id': '340',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813660,
#     'eightd_has_available_keys': True},
#    {'station_id': '341',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813638,
#     'eightd_has_available_keys': False},
#    {'station_id': '342',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813666,
#     'eightd_has_available_keys': False},
#    {'station_id': '343',
#     'num_bikes_available': 17,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813703,
#     'eightd_has_available_keys': False},
#    {'station_id': '344',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812886,
#     'eightd_has_available_keys': False},
#    {'station_id': '346',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813285,
#     'eightd_has_available_keys': False},
#    {'station_id': '347',
#     'num_bikes_available': 35,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813427,
#     'eightd_has_available_keys': False},
#    {'station_id': '349',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 60,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813541,
#     'eightd_has_available_keys': False},
#    {'station_id': '350',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813636,
#     'eightd_has_available_keys': False},
#    {'station_id': '351',
#     'num_bikes_available': 39,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582811871,
#     'eightd_has_available_keys': False},
#    {'station_id': '353',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813557,
#     'eightd_has_available_keys': False},
#    {'station_id': '354',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812769,
#     'eightd_has_available_keys': False},
#    {'station_id': '355',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813411,
#     'eightd_has_available_keys': False},
#    {'station_id': '356',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812912,
#     'eightd_has_available_keys': False},
#    {'station_id': '358',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 47,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813797,
#     'eightd_has_available_keys': False},
#    {'station_id': '360',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813663,
#     'eightd_has_available_keys': False},
#    {'station_id': '361',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 33,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813762,
#     'eightd_has_available_keys': False},
#    {'station_id': '362',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 36,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813635,
#     'eightd_has_available_keys': False},
#    {'station_id': '363',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813095,
#     'eightd_has_available_keys': False},
#    {'station_id': '364',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813517,
#     'eightd_has_available_keys': False},
#    {'station_id': '366',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582811619,
#     'eightd_has_available_keys': False},
#    {'station_id': '368',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813734,
#     'eightd_has_available_keys': True},
#    {'station_id': '369',
#     'num_bikes_available': 42,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813764,
#     'eightd_has_available_keys': False},
#    {'station_id': '372',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582810411,
#     'eightd_has_available_keys': False},
#    {'station_id': '373',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582810699,
#     'eightd_has_available_keys': False},
#    {'station_id': '376',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812024,
#     'eightd_has_available_keys': False},
#    {'station_id': '377',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813756,
#     'eightd_has_available_keys': False},
#    {'station_id': '379',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 34,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813820,
#     'eightd_has_available_keys': False},
#    {'station_id': '380',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 35,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813806,
#     'eightd_has_available_keys': False},
#    {'station_id': '383',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813710,
#     'eightd_has_available_keys': False},
#    {'station_id': '385',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813814,
#     'eightd_has_available_keys': False},
#    {'station_id': '386',
#     'num_bikes_available': 39,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813635,
#     'eightd_has_available_keys': False},
#    {'station_id': '387',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813738,
#     'eightd_has_available_keys': False},
#    {'station_id': '388',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812863,
#     'eightd_has_available_keys': False},
#    {'station_id': '389',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813479,
#     'eightd_has_available_keys': False},
#    {'station_id': '390',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813571,
#     'eightd_has_available_keys': False},
#    {'station_id': '391',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813181,
#     'eightd_has_available_keys': False},
#    {'station_id': '392',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813225,
#     'eightd_has_available_keys': False},
#    {'station_id': '393',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 36,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813485,
#     'eightd_has_available_keys': False},
#    {'station_id': '394',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813104,
#     'eightd_has_available_keys': False},
#    {'station_id': '396',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582810649,
#     'eightd_has_available_keys': False},
#    {'station_id': '397',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813403,
#     'eightd_has_available_keys': False},
#    {'station_id': '398',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813612,
#     'eightd_has_available_keys': False},
#    {'station_id': '399',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813818,
#     'eightd_has_available_keys': False},
#    {'station_id': '400',
#     'num_bikes_available': 4,
# ...
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582795978,
#     'eightd_has_available_keys': False},
#    {'station_id': '3862',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796132,
#     'eightd_has_available_keys': False},
#    {'station_id': '3863',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582811690,
#     'eightd_has_available_keys': False},
#    {'station_id': '3864',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796099,
#     'eightd_has_available_keys': False},
#    {'station_id': '3865',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796026,
#     'eightd_has_available_keys': False},
#    {'station_id': '3866',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582809506,
#     'eightd_has_available_keys': False},
#    {'station_id': '3867',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796116,
#     'eightd_has_available_keys': False},
#    {'station_id': '3868',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582804627,
#     'eightd_has_available_keys': False},
#    {'station_id': '3869',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582795991,
#     'eightd_has_available_keys': False},
#    {'station_id': '3870',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582810384,
#     'eightd_has_available_keys': False},
#    {'station_id': '3871',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582795962,
#     'eightd_has_available_keys': False},
#    {'station_id': '3872',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797296,
#     'eightd_has_available_keys': False},
#    {'station_id': '3873',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797162,
#     'eightd_has_available_keys': False},
#    {'station_id': '3874',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813690,
#     'eightd_has_available_keys': False},
#    {'station_id': '3875',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797310,
#     'eightd_has_available_keys': False},
#    {'station_id': '3876',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812913,
#     'eightd_has_available_keys': False},
#    {'station_id': '3877',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797380,
#     'eightd_has_available_keys': False},
#    {'station_id': '3878',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796111,
#     'eightd_has_available_keys': False},
#    {'station_id': '3879',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582811922,
#     'eightd_has_available_keys': False},
#    {'station_id': '3880',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582806787,
#     'eightd_has_available_keys': False},
#    {'station_id': '3881',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813613,
#     'eightd_has_available_keys': False},
#    {'station_id': '3882',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582810474,
#     'eightd_has_available_keys': False},
#    {'station_id': '3883',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796147,
#     'eightd_has_available_keys': False},
#    {'station_id': '3884',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797278,
#     'eightd_has_available_keys': False},
#    {'station_id': '3885',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797228,
#     'eightd_has_available_keys': False},
#    {'station_id': '3886',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582809971,
#     'eightd_has_available_keys': False},
#    {'station_id': '3887',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797158,
#     'eightd_has_available_keys': False},
#    {'station_id': '3888',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797159,
#     'eightd_has_available_keys': False},
#    {'station_id': '3890',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582808457,
#     'eightd_has_available_keys': False},
#    {'station_id': '3891',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796066,
#     'eightd_has_available_keys': False},
#    {'station_id': '3892',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582808167,
#     'eightd_has_available_keys': False},
#    {'station_id': '3893',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812122,
#     'eightd_has_available_keys': False},
#    {'station_id': '3895',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796035,
#     'eightd_has_available_keys': False},
#    {'station_id': '3896',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582804264,
#     'eightd_has_available_keys': False},
#    {'station_id': '3897',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582798357,
#     'eightd_has_available_keys': False},
#    {'station_id': '3898',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 53,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813740,
#     'eightd_has_available_keys': False},
#    {'station_id': '3899',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813017,
#     'eightd_has_available_keys': False},
#    {'station_id': '3900',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813578,
#     'eightd_has_available_keys': False},
#    {'station_id': '3901',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797174,
#     'eightd_has_available_keys': False},
#    {'station_id': '3902',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797191,
#     'eightd_has_available_keys': False},
#    {'station_id': '3903',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797327,
#     'eightd_has_available_keys': False},
#    {'station_id': '3905',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813699,
#     'eightd_has_available_keys': False},
#    {'station_id': '3907',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582808341,
#     'eightd_has_available_keys': False},
#    {'station_id': '3909',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797170,
#     'eightd_has_available_keys': False},
#    {'station_id': '3910',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797296,
#     'eightd_has_available_keys': False},
#    {'station_id': '3911',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813761,
#     'eightd_has_available_keys': False},
#    {'station_id': '3913',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582783965,
#     'eightd_has_available_keys': False},
#    {'station_id': '3914',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582807501,
#     'eightd_has_available_keys': False},
#    {'station_id': '3916',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813739,
#     'eightd_has_available_keys': True},
#    {'station_id': '3917',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813529,
#     'eightd_has_available_keys': False},
#    {'station_id': '3918',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813767,
#     'eightd_has_available_keys': False}]}}

# %%
# Convert the data into a Pandas dataframe:
station_status_df = pd.DataFrame(station_status_data['data']['stations'])
station_status_df.head()
# Out:
#   station_id  num_bikes_available  num_ebikes_available  num_bikes_disabled  \
# 0        304                   11                     1                   0
# 1        359                   21                     3                   2
# 2        367                    5                     0                   0
# 3        402                   10                     2                   0
# 4       3443                    6                     2                   1
#
#    num_docks_available  num_docks_disabled  is_installed  is_renting  \
# 0                   22                   0             1           1
# 1                   41                   0             1           1
# 2                   29                   0             1           1
# 3                   29                   0             1           1
# 4                   34                   0             1           1
#
#    is_returning  last_reported  eightd_has_available_keys  \
# 0             1     1582813735                       True
# 1             1     1582813593                      False
# 2             1     1582813748                      False
# 3             1     1582813797                      False
# 4             1     1582813759                      False
#
#                      eightd_active_station_services
# 0  [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'}]
# 1  [{'id': '2e104e31-606a-44af-8b25-ceaffc338489'}]
# 2  [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0'}]
# 3  [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'}]
# 4  [{'id': '286d75b2-088f-4a79-bf7d-223928be711c'}]

# %%
station_status_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 12 columns):
# station_id                        935 non-null object
# num_bikes_available               935 non-null int64
# num_ebikes_available              935 non-null int64
# num_bikes_disabled                935 non-null int64
# num_docks_available               935 non-null int64
# num_docks_disabled                935 non-null int64
# is_installed                      935 non-null int64
# is_renting                        935 non-null int64
# is_returning                      935 non-null int64
# last_reported                     935 non-null int64
# eightd_has_available_keys         935 non-null bool
# eightd_active_station_services    6 non-null object
# dtypes: bool(1), int64(9), object(2)
# memory usage: 81.4+ KB

# %% [markdown]
# ---
#
# ## 3.  Import Trip Data (from .csv)
# - We'll create a pandas dataframe from the data.
# - See https://s3.amazonaws.com/tripdata/index.html for available datasets.

# %%
# I just randomly grabbed this file:
bike_trips_df = pd.read_csv('202001-citibike-tripdata.csv')

# %%
# bike_trips_df.columns

# Using `list()` formats things a little better:
list(bike_trips_df.columns)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
bike_trips_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# 0               -73.981656             307      Canal St & Rutgers St
# 1               -73.979453            3300  Prospect Park West & 8 St
# 2               -73.974498             259    South St & Whitehall St
# 3               -74.006180             490            8 Ave & W 33 St
# 4               -73.958014            3637    Fulton St & Waverly Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.714275             -73.989900   30326  Subscriber
# 1             40.665147             -73.976376   17105    Customer
# 2             40.701221             -74.012342   40177  Subscriber
# 3             40.751551             -73.993934   27690  Subscriber
# 4             40.683239             -73.965996   32583  Subscriber
#
#    birth year  gender
# 0        1992       1
# 1        1969       1
# 2        1963       1
# 3        1980       1
# 4        1982       1

# %% [markdown]
# ---
#
# ## Create a VeRoViz "nodes" Dataframe
# - We'll populate this with data from Station Info and Station Status
# - We'll also hard-code some columns

# %%
nodes = vrv.initDataframe('nodes')

# %%
# Here are the columns we'll need to populate:
list(nodes.columns)
# Out:
# ['id',
#  'lat',
#  'lon',
#  'altMeters',
#  'nodeName',
#  'nodeType',
#  'leafletIconPrefix',
#  'leafletIconType',
#  'leafletColor',
#  'leafletIconText',
#  'cesiumIconType',
#  'cesiumColor',
#  'cesiumIconText']

# %%
# Here are the columns from our "Station Info":
list(station_info_df.columns)
# Out:
# ['station_id',
#  'external_id',
#  'name',
#  'short_name',
#  'lat',
#  'lon',
#  'region_id',
#  'rental_methods',
#  'capacity',
#  'rental_url',
#  'electric_bike_surcharge_waiver',
#  'eightd_has_key_dispenser',
#  'eightd_station_services',
#  'has_kiosk']

# %%
# An example to show the syntax for displaying 2 particular columns from a df:
station_info_df[['lat', 'lon']].head()
# Out:
#          lat        lon
# 0  40.704633 -74.013617
# 1  40.755103 -73.974987
# 2  40.758281 -73.970694
# 3  40.740343 -73.989551
# 4  40.761330 -73.979820

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodes = vrv.initDataframe('nodes')

# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied 
#       just a single column first.  
nodes['id'] = station_info_df['station_id'].values
nodes[['id', 'lat', 'lon', 'nodeName']] = station_info_df[['station_id', 'lat', 'lon', 'name']].values
nodes[['leafletIconText', 'cesiumIconText']] = station_info_df[['name', 'station_id']].values

# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodes.loc[:,'altMeters'] = 0
nodes.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType', 'leafletColor']] = [
             'CitiBikeStation',  'fa',                'bicycle',         'orange']
nodes.loc[:,['cesiumIconType', 'cesiumColor']] = ['pin', 'Cesium.Color.ORANGE']

# %% [markdown]
# HW 1) CHANGE COLOR OF THE NODES
# ---
# DIFFERENT TO REPRESENT THE VOLUME OF THE STATIONS
# -
#
# 1) Green - There are docks and bikes avaliable
#
# 2) LightRed/Yellow - There are only docs avaliable
#
# 3) Red - There are NO docks or bikes avaliable

# %%
# insert Color here 

# Convert the data into a Pandas dataframe:
station_status_df = pd.DataFrame(station_status_data['data']['stations'])
station_status_df['colors'] = None
station_status_df['CESIUMcolors'] = None
station_status_df['OnRoute'] = None
station_status_df.head()
# Out:
#   station_id  num_bikes_available  num_ebikes_available  num_bikes_disabled  \
# 0        304                   11                     1                   0
# 1        359                   21                     3                   2
# 2        367                    5                     0                   0
# 3        402                   10                     2                   0
# 4       3443                    6                     2                   1
#
#    num_docks_available  num_docks_disabled  is_installed  is_renting  \
# 0                   22                   0             1           1
# 1                   41                   0             1           1
# 2                   29                   0             1           1
# 3                   29                   0             1           1
# 4                   34                   0             1           1
#
#    is_returning  last_reported  eightd_has_available_keys  \
# 0             1     1582813735                       True
# 1             1     1582813593                      False
# 2             1     1582813748                      False
# 3             1     1582813797                      False
# 4             1     1582813759                      False
#
#                      eightd_active_station_services colors CESIUMcolors  \
# 0  [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'}]   None         None
# 1  [{'id': '2e104e31-606a-44af-8b25-ceaffc338489'}]   None         None
# 2  [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0'}]   None         None
# 3  [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'}]   None         None
# 4  [{'id': '286d75b2-088f-4a79-bf7d-223928be711c'}]   None         None
#
#   OnRoute
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
for i in station_status_df.index:
    if station_status_df['num_docks_available'][i] >= 5 and station_status_df['num_bikes_available'][i] >= 5:
        station_status_df['colors'][i] = 'green'
        station_status_df['CESIUMcolors'][i] = 'Cesium.Color.GREEN'
    elif station_status_df['num_docks_available'][i] <= 5:
        station_status_df['colors'][i] = 'lightred'
        station_status_df['CESIUMcolors'][i] = 'Cesium.Color.YELLOW'
    elif station_status_df['num_bikes_available'][i] <= 5:
        station_status_df['colors'][i] = 'red'
        station_status_df['CESIUMcolors'][i] = 'Cesium.Color.RED'
station_status_df.tail(10)
# Out:
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     station_id  num_bikes_available  num_ebikes_available  num_bikes_disabled  \
# 925       3905                   11                     0                   1
# 926       3907                    1                     0                   0
# 927       3909                    3                     0                   0
# 928       3910                    0                     0                   0
# 929       3911                   11                     0                   0
# 930       3913                   19                     0                   0
# 931       3914                    0                     0                   1
# 932       3916                   28                     0                   1
# 933       3917                    5                     1                   0
# 934       3918                    2                     1                   0
#
#      num_docks_available  num_docks_disabled  is_installed  is_renting  \
# 925                   15                   0             1           1
# 926                   16                   0             1           1
# 927                   17                   0             1           1
# 928                   17                   0             1           1
# 929                   11                   0             1           1
# 930                    0                   0             1           1
# 931                   38                   0             1           1
# 932                   16                   0             1           1
# 933                   26                   0             1           1
# 934                   28                   0             1           1
#
#      is_returning  last_reported  eightd_has_available_keys  \
# 925             1     1582813699                      False
# 926             1     1582808341                      False
# 927             1     1582797170                      False
# 928             1     1582797296                      False
# 929             1     1582813761                      False
# 930             1     1582783965                      False
# 931             1     1582807501                      False
# 932             1     1582813739                       True
# 933             1     1582813529                      False
# 934             1     1582813767                      False
#
#     eightd_active_station_services    colors         CESIUMcolors OnRoute
# 925                            NaN     green   Cesium.Color.GREEN    None
# 926                            NaN       red     Cesium.Color.RED    None
# 927                            NaN       red     Cesium.Color.RED    None
# 928                            NaN       red     Cesium.Color.RED    None
# 929                            NaN     green   Cesium.Color.GREEN    None
# 930                            NaN  lightred  Cesium.Color.YELLOW    None
# 931                            NaN       red     Cesium.Color.RED    None
# 932                            NaN     green   Cesium.Color.GREEN    None
# 933                            NaN     green   Cesium.Color.GREEN    None
# 934                            NaN       red     Cesium.Color.RED    None

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodes = vrv.initDataframe('nodes')
# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied
#       just a single column first.
nodes['id'] = station_info_df['station_id'].values
nodes[[ 'lat', 'lon', 'nodeName']] = station_info_df[[ 'lat', 'lon', 'name']].values
nodes[['leafletIconText', 'cesiumIconText']] = station_info_df[['name', 'station_id']].values
# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodes['leafletColor'] = station_status_df['colors']
nodes['cesiumColor'] = station_status_df['CESIUMcolors']
nodes.loc[:,'altMeters'] = 0
nodes.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType']] = [
             'Citibike Station', 'fa', 'bicycle']
nodes.loc[:,'cesiumIconType'] = 'pin'

# %% [markdown]
# HW 2) SET UP A NEW DATABASE FOR BIKE 14530 AND ONLY SHOW THOSE STATIONS
# ---

# %%
value_list=[14530]
bike141_info_df = bike_trips_df[bike_trips_df.bikeid.isin(value_list)]
bike141_info_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 26822             548  2020-01-02 09:25:11.9390  2020-01-02 09:34:20.3600
# 50614            1061  2020-01-02 18:16:45.1630  2020-01-02 18:34:26.5780
# 134556            400  2020-01-05 14:27:01.9750  2020-01-05 14:33:42.1210
# 171702            301  2020-01-06 16:10:01.6600  2020-01-06 16:15:03.0080
# 175456            167  2020-01-06 17:15:51.0260  2020-01-06 17:18:38.1240
# ...               ...                       ...                       ...
# 1183146          1689  2020-01-30 18:30:48.6870  2020-01-30 18:58:58.0690
# 1186951           388  2020-01-30 19:30:54.8530  2020-01-30 19:37:23.7710
# 1191584           884  2020-01-30 21:52:15.6920  2020-01-30 22:07:00.2830
# 1200708           515  2020-01-31 08:27:54.4500  2020-01-31 08:36:30.1120
# 1201970           529  2020-01-31 08:41:55.1210  2020-01-31 08:50:44.3750
#
#          start station id           start station name  \
# 26822                 261         Johnson St & Gold St
# 50614                2000     Front St & Washington St
# 134556               3414     Bergen St & Flatbush Ave
# 171702               3486    Schermerhorn St & Bond St
# 175456                241  DeKalb Ave & S Portland Ave
# ...                   ...                          ...
# 1183146               362           Broadway & W 37 St
# 1186951               151     Cleveland Pl & Spring St
# 1191584               311       Norfolk St & Broome St
# 1200708               297              E 15 St & 3 Ave
# 1201970               379              W 31 St & 7 Ave
#
#          start station latitude  start station longitude  end station id  \
# 26822                 40.694749               -73.983625            2000
# 50614                 40.702551               -73.989402            3414
# 134556                40.680945               -73.975673            3486
# 171702                40.688417               -73.984517             241
# 175456                40.689810               -73.974931             324
# ...                         ...                      ...             ...
# 1183146               40.751726               -73.987535             151
# 1186951               40.722104               -73.997249             311
# 1191584               40.717227               -73.988021             297
# 1200708               40.734232               -73.986923             379
# 1201970               40.749156               -73.991600             496
#
#                     end station name  end station latitude  \
# 26822       Front St & Washington St             40.702551
# 50614       Bergen St & Flatbush Ave             40.680945
# 134556     Schermerhorn St & Bond St             40.688417
# 171702   DeKalb Ave & S Portland Ave             40.689810
# 175456       DeKalb Ave & Hudson Ave             40.689888
# ...                              ...                   ...
# 1183146     Cleveland Pl & Spring St             40.722104
# 1186951       Norfolk St & Broome St             40.717227
# 1191584              E 15 St & 3 Ave             40.734232
# 1200708              W 31 St & 7 Ave             40.749156
# 1201970              E 16 St & 5 Ave             40.737262
#
#          end station longitude  bikeid    usertype  birth year  gender
# 26822               -73.989402   14530  Subscriber        1987       1
# 50614               -73.975673   14530  Subscriber        1992       1
# 134556              -73.984517   14530    Customer        1969       0
# 171702              -73.974931   14530  Subscriber        1985       1
# 175456              -73.981013   14530  Subscriber        1998       1
# ...                        ...     ...         ...         ...     ...
# 1183146             -73.997249   14530    Customer        1995       1
# 1186951             -73.988021   14530  Subscriber        1973       1
# 1191584             -73.986923   14530  Subscriber        1983       1
# 1200708             -73.991600   14530  Subscriber        1993       1
# 1201970             -73.992390   14530  Subscriber        1981       1
#
# [74 rows x 15 columns]

# %%
stationList1 = bike141_info_df['end station id'].unique().tolist()
stationList2 = bike141_info_df['start station id'].unique().tolist()
stationList1 = list(map(int, stationList1))

bike141_info_df
bike141_info_df['colors'] = None
bike141_info_df['CESIUMcolors'] = None
bike141_info_df['capacity'] = None
bike141_info_df.tail()
# Out:
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          tripduration                 starttime                  stoptime  \
# 1183146          1689  2020-01-30 18:30:48.6870  2020-01-30 18:58:58.0690
# 1186951           388  2020-01-30 19:30:54.8530  2020-01-30 19:37:23.7710
# 1191584           884  2020-01-30 21:52:15.6920  2020-01-30 22:07:00.2830
# 1200708           515  2020-01-31 08:27:54.4500  2020-01-31 08:36:30.1120
# 1201970           529  2020-01-31 08:41:55.1210  2020-01-31 08:50:44.3750
#
#          start station id        start station name  start station latitude  \
# 1183146               362        Broadway & W 37 St               40.751726
# 1186951               151  Cleveland Pl & Spring St               40.722104
# 1191584               311    Norfolk St & Broome St               40.717227
# 1200708               297           E 15 St & 3 Ave               40.734232
# 1201970               379           W 31 St & 7 Ave               40.749156
#
#          start station longitude  end station id          end station name  \
# 1183146               -73.987535             151  Cleveland Pl & Spring St
# 1186951               -73.997249             311    Norfolk St & Broome St
# 1191584               -73.988021             297           E 15 St & 3 Ave
# 1200708               -73.986923             379           W 31 St & 7 Ave
# 1201970               -73.991600             496           E 16 St & 5 Ave
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 1183146             40.722104             -73.997249   14530    Customer
# 1186951             40.717227             -73.988021   14530  Subscriber
# 1191584             40.734232             -73.986923   14530  Subscriber
# 1200708             40.749156             -73.991600   14530  Subscriber
# 1201970             40.737262             -73.992390   14530  Subscriber
#
#          birth year  gender colors CESIUMcolors capacity
# 1183146        1995       1   None         None     None
# 1186951        1973       1   None         None     None
# 1191584        1983       1   None         None     None
# 1200708        1993       1   None         None     None
# 1201970        1981       1   None         None     None

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodes2 = vrv.initDataframe('nodes')
# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied
#       just a single column first.
nodes2['id'] = bike141_info_df['start station id'].values
nodes2[['lat', 'lon', 'nodeName']] = bike141_info_df[[ 'start station latitude', 'start station longitude', 'start station name']].values
nodes2[['leafletIconText', 'cesiumIconText']] = bike141_info_df[[ 'start station name', 'start station id']].values
# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodes2['leafletColor'] = station_status_df['colors']
nodes2['cesiumColor'] = station_status_df['CESIUMcolors']
nodes2.loc[:,'altMeters'] = 0
nodes2.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType']] = [
             'Citibike Station', 'fa', 'bicycle']
nodes2.loc[:,'cesiumIconType'] = 'pin'

# %%
nodes2.head()
# Out:
#      id        lat        lon  altMeters                     nodeName  \
# 0   261  40.694749 -73.983625          0         Johnson St & Gold St
# 1  2000  40.702551 -73.989402          0     Front St & Washington St
# 2  3414  40.680945 -73.975673          0     Bergen St & Flatbush Ave
# 3  3486  40.688417 -73.984517          0    Schermerhorn St & Bond St
# 4   241  40.689810 -73.974931          0  DeKalb Ave & S Portland Ave
#
#            nodeType leafletIconPrefix leafletIconType leafletColor  \
# 0  Citibike Station                fa         bicycle        green
# 1  Citibike Station                fa         bicycle        green
# 2  Citibike Station                fa         bicycle        green
# 3  Citibike Station                fa         bicycle        green
# 4  Citibike Station                fa         bicycle        green
#
#                leafletIconText cesiumIconType         cesiumColor  \
# 0         Johnson St & Gold St            pin  Cesium.Color.GREEN
# 1     Front St & Washington St            pin  Cesium.Color.GREEN
# 2     Bergen St & Flatbush Ave            pin  Cesium.Color.GREEN
# 3    Schermerhorn St & Bond St            pin  Cesium.Color.GREEN
# 4  DeKalb Ave & S Portland Ave            pin  Cesium.Color.GREEN
#
#    cesiumIconText
# 0             261
# 1            2000
# 2            3414
# 3            3486
# 4             241

# %%
# Show all of the nodes on a Leaflet map:
vrv.createLeaflet(nodes=nodes2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
#
# ## Create a VeRoViz "assignments" Dataframe
# - We'll populate this with trip data
# - We'll also hard-code some columns

# %%
# NOTE:  VeRoViz also has an "arcs" dataframe,
#        but it doesn't have time-related columns.
arcs = vrv.initDataframe('arcs')
list(arcs.columns)

# We won't use the "arcs" dataframe
# Out:
# ['odID',
#  'objectID',
#  'startLat',
#  'startLon',
#  'endLat',
#  'endLon',
#  'leafletColor',
#  'leafletWeight',
#  'leafletStyle',
#  'leafletOpacity',
#  'useArrows',
#  'cesiumColor',
#  'cesiumWeight',
#  'cesiumStyle',
#  'cesiumOpacity']

# %%
# Initialize an empty "assignments" dataframe:
assignments = vrv.initDataframe('assignments')
assignments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 22 columns):
# odID              0 non-null object
# objectID          0 non-null object
# modelFile         0 non-null object
# modelScale        0 non-null object
# modelMinPxSize    0 non-null object
# startTimeSec      0 non-null object
# startLat          0 non-null object
# startLon          0 non-null object
# startAltMeters    0 non-null object
# endTimeSec        0 non-null object
# endLat            0 non-null object
# endLon            0 non-null object
# endAltMeters      0 non-null object
# leafletColor      0 non-null object
# leafletWeight     0 non-null object
# leafletStyle      0 non-null object
# leafletOpacity    0 non-null object
# useArrows         0 non-null object
# cesiumColor       0 non-null object
# cesiumWeight      0 non-null object
# cesiumStyle       0 non-null object
# cesiumOpacity     0 non-null object
# dtypes: object(22)
# memory usage: 0.0+ bytes

# %% [markdown]
# ### Here's the plan:
# - These columns will come directly from bike trip data:
#     - `objectID` (from `bikeid`)
#     - `startLat` and `startLon` (from `start station latitude` and `start station longitude`)
#     - `endLat` and `endLon` (from `end station latitude` and `end station longitude`)
# - These columns will need to be calculated:
#     - `startTimeSec` (from `starttime`, but converted to "seconds since the first event")
#     - `endTimeSec`   (from `starttime` and `tripduration`, or `starttime` and `stoptime`)
#     - We'll create some new columns in `bike_trips_df` to hold our calculations.  Then we'll copy these calculated columns into our assignments dataframe.
# - This column will need to be auto generated:
#     - `odID` (each origin/destination pair should get a unique integer)
# - The remaining columns will be hard-coded (for now)

# %%
# What is the first start time in our bike_trips_df?
min(bike_trips_df['starttime'])
# Out:
# '2020-01-01 00:00:55.3900'

# %%
# Add a new column to bike_trips_df...

# This next command will produce a "timestamp" (days HH:MM:SS.ms) 
# showing the time since the first observed `starttime`:
bike_trips_df['timeAfterStart'] = pd.to_datetime(bike_trips_df['starttime']) - \
                                  pd.to_datetime(min(bike_trips_df['starttime']))

# Now, convert this to a decimal number of seconds:
bike_trips_df['timeAfterStart'] = bike_trips_df['timeAfterStart'].dt.total_seconds().astype(int)

bike_trips_df['timeAfterStart'].head()
# Out:
# 0     0
# 1    12
# 2    46
# 3    50
# 4    50
# Name: timeAfterStart, dtype: int32

# %%
# Just for fun, here's the time differences between start/stop times:
pd.to_datetime(bike_trips_df['stoptime']) - pd.to_datetime(bike_trips_df['starttime'])
# Out:
# 0         00:13:09.757000
# 1         00:25:41.076000
# 2         00:24:24.871000
# 3         00:09:52.594000
# 4         00:11:42.452000
#                 ...
# 1240591   00:26:27.607000
# 1240592   00:03:42.831000
# 1240593   00:02:43.862000
# 1240594   00:05:27.148000
# 1240595   00:08:04.146000
# Length: 1240596, dtype: timedelta64[ns]

# %%
# In one cell, we'll create our assignments dataframe.

# Make sure we're starting with an empty dataframe:
assignments = vrv.initDataframe('assignments')

# Copy over the static values.
# We'll start by copying a single column, to avoid the size mis-match issue:
assignments['objectID'] = bike_trips_df['bikeid']
assignments[['startLat', 'startLon', 'endLat', 'endLon']] = bike_trips_df[['start station latitude', 
                                                                          'start station longitude',
                                                                          'end station latitude',
                                                                          'end station longitude']].values

# Copy our new calculated column:
assignments['startTimeSec'] = bike_trips_df['timeAfterStart'].values

# Use the calculated column and tripduration to get the end time (in seconds):
assignments['endTimeSec'] = (bike_trips_df['timeAfterStart'] + bike_trips_df['tripduration']).values

# Fill in the rest of our assignments df with some hard-coded values:
# (we'll probably want to revisit this later)
assignments.loc[:,['modelFile', 'modelScale', 'modelMinPxSize', 'startAltMeters', 'endAltMeters', 
                   'leafletColor', 'leafletWeight', 'leafletStyle', 'leafletOpacity', 'useArrows',
                   'cesiumColor', 'cesiumWeight', 'cesiumStyle', 'cesiumOpacity']] = \
                  ['veroviz/models/car_blue.gltf', 100, 45, 0, 0, 
                   'blue', 2, 'solid', 0.8, False, 
                   'Cesium.Color.BLUE', 2, 'solid', 0.7]

# Finally (for now), let's generate a unique odID value for each row.
# This will make sense only if we assume that each row corresponds to a specific
# O/D pair.  Conversely, if we have turn-by-turn arcs, we'll need to group
# multiple rows into the same O/D pair.  We'll tackle that case if/when 
# we encounter it.
assignments.loc[:,'odID'] = list(range(0, len(assignments)))

# %%
# Display what we've created:
assignments.head()
# Out:
#    odID  objectID                     modelFile  modelScale  modelMinPxSize  \
# 0     0     30326  veroviz/models/car_blue.gltf         100              45
# 1     1     17105  veroviz/models/car_blue.gltf         100              45
# 2     2     40177  veroviz/models/car_blue.gltf         100              45
# 3     3     27690  veroviz/models/car_blue.gltf         100              45
# 4     4     32583  veroviz/models/car_blue.gltf         100              45
#
#    startTimeSec   startLat   startLon  startAltMeters  endTimeSec  ...  \
# 0             0  40.732219 -73.981656               0         789  ...
# 1            12  40.661063 -73.979453               0        1553  ...
# 2            46  40.743227 -73.974498               0        1510  ...
# 3            50  40.736529 -74.006180               0         642  ...
# 4            50  40.694546 -73.958014               0         752  ...
#
#    endAltMeters  leafletColor  leafletWeight leafletStyle  leafletOpacity  \
# 0             0          blue              2        solid             0.8
# 1             0          blue              2        solid             0.8
# 2             0          blue              2        solid             0.8
# 3             0          blue              2        solid             0.8
# 4             0          blue              2        solid             0.8
#
#   useArrows        cesiumColor  cesiumWeight cesiumStyle  cesiumOpacity
# 0     False  Cesium.Color.BLUE             2       solid            0.7
# 1     False  Cesium.Color.BLUE             2       solid            0.7
# 2     False  Cesium.Color.BLUE             2       solid            0.7
# 3     False  Cesium.Color.BLUE             2       solid            0.7
# 4     False  Cesium.Color.BLUE             2       solid            0.7
#
# [5 rows x 22 columns]

# %% [markdown]
# ---
#
# ### Create a Leaflet map
# - We have a lot of bikes...let's just display one.

# %%
# I'll just choose the bike with the smallest ID number:
assignments[assignments['objectID'] == min(assignments['objectID'])]
# Out:
#             odID  objectID                     modelFile  modelScale  \
# 26822      26822     14530  veroviz/models/car_blue.gltf         100
# 50614      50614     14530  veroviz/models/car_blue.gltf         100
# 134556    134556     14530  veroviz/models/car_blue.gltf         100
# 171702    171702     14530  veroviz/models/car_blue.gltf         100
# 175456    175456     14530  veroviz/models/car_blue.gltf         100
# ...          ...       ...                           ...         ...
# 1183146  1183146     14530  veroviz/models/car_blue.gltf         100
# 1186951  1186951     14530  veroviz/models/car_blue.gltf         100
# 1191584  1191584     14530  veroviz/models/car_blue.gltf         100
# 1200708  1200708     14530  veroviz/models/car_blue.gltf         100
# 1201970  1201970     14530  veroviz/models/car_blue.gltf         100
#
#          modelMinPxSize  startTimeSec   startLat   startLon  startAltMeters  \
# 26822                45        120256  40.694749 -73.983625               0
# 50614                45        152149  40.702551 -73.989402               0
# 134556               45        397566  40.680945 -73.975673               0
# 171702               45        490146  40.688417 -73.984517               0
# 175456               45        494095  40.689810 -73.974931               0
# ...                 ...           ...        ...        ...             ...
# 1183146              45       2572193  40.751726 -73.987535               0
# 1186951              45       2575799  40.722104 -73.997249               0
# 1191584              45       2584280  40.717227 -73.988021               0
# 1200708              45       2622419  40.734232 -73.986923               0
# 1201970              45       2623259  40.749156 -73.991600               0
#
#          endTimeSec  ...  endAltMeters  leafletColor  leafletWeight  \
# 26822        120804  ...             0          blue              2
# 50614        153210  ...             0          blue              2
# 134556       397966  ...             0          blue              2
# 171702       490447  ...             0          blue              2
# 175456       494262  ...             0          blue              2
# ...             ...  ...           ...           ...            ...
# 1183146     2573882  ...             0          blue              2
# 1186951     2576187  ...             0          blue              2
# 1191584     2585164  ...             0          blue              2
# 1200708     2622934  ...             0          blue              2
# 1201970     2623788  ...             0          blue              2
#
#         leafletStyle  leafletOpacity useArrows        cesiumColor  \
# 26822          solid             0.8     False  Cesium.Color.BLUE
# 50614          solid             0.8     False  Cesium.Color.BLUE
# 134556         solid             0.8     False  Cesium.Color.BLUE
# 171702         solid             0.8     False  Cesium.Color.BLUE
# 175456         solid             0.8     False  Cesium.Color.BLUE
# ...              ...             ...       ...                ...
# 1183146        solid             0.8     False  Cesium.Color.BLUE
# 1186951        solid             0.8     False  Cesium.Color.BLUE
# 1191584        solid             0.8     False  Cesium.Color.BLUE
# 1200708        solid             0.8     False  Cesium.Color.BLUE
# 1201970        solid             0.8     False  Cesium.Color.BLUE
#
#          cesiumWeight cesiumStyle  cesiumOpacity
# 26822               2       solid            0.7
# 50614               2       solid            0.7
# 134556              2       solid            0.7
# 171702              2       solid            0.7
# 175456              2       solid            0.7
# ...               ...         ...            ...
# 1183146             2       solid            0.7
# 1186951             2       solid            0.7
# 1191584             2       solid            0.7
# 1200708             2       solid            0.7
# 1201970             2       solid            0.7
#
# [74 rows x 22 columns]

# %%
# Show all of the arcs for this particular bike:
vrv.createLeaflet(arcs=assignments[assignments['objectID'] == 14530])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add a new column to bike_trips_df...

# This next command will produce a "timestamp" (days HH:MM:SS.ms) 
# showing the time since the first observed `starttime`:
bike141_info_df['timeAfterStart'] = pd.to_datetime(bike141_info_df['starttime']) - \
                                  pd.to_datetime(min(bike141_info_df['starttime']))

# Now, convert this to a decimal number of seconds:
bike141_info_df['timeAfterStart'] = bike141_info_df['timeAfterStart'].dt.total_seconds().astype(int)

bike141_info_df['timeAfterStart'].head()
# Out:
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# 26822          0
# 50614      31893
# 134556    277310
# 171702    369889
# 175456    373839
# Name: timeAfterStart, dtype: int32

# %% [markdown]
# HW 3) ADD IN NEW CITIBIKE MOVES WITH FOR LOOP
# ---

# %%
for i in bike141_info_df.index:
    bike141_info_df['colors'][i] = 'green'
    bike141_info_df['CESIUMcolors'][i] = 'Cesium.Color.GREEN'
bike141_info_df
# Out:
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          tripduration                 starttime                  stoptime  \
# 26822             548  2020-01-02 09:25:11.9390  2020-01-02 09:34:20.3600
# 50614            1061  2020-01-02 18:16:45.1630  2020-01-02 18:34:26.5780
# 134556            400  2020-01-05 14:27:01.9750  2020-01-05 14:33:42.1210
# 171702            301  2020-01-06 16:10:01.6600  2020-01-06 16:15:03.0080
# 175456            167  2020-01-06 17:15:51.0260  2020-01-06 17:18:38.1240
# ...               ...                       ...                       ...
# 1183146          1689  2020-01-30 18:30:48.6870  2020-01-30 18:58:58.0690
# 1186951           388  2020-01-30 19:30:54.8530  2020-01-30 19:37:23.7710
# 1191584           884  2020-01-30 21:52:15.6920  2020-01-30 22:07:00.2830
# 1200708           515  2020-01-31 08:27:54.4500  2020-01-31 08:36:30.1120
# 1201970           529  2020-01-31 08:41:55.1210  2020-01-31 08:50:44.3750
#
#          start station id           start station name  \
# 26822                 261         Johnson St & Gold St
# 50614                2000     Front St & Washington St
# 134556               3414     Bergen St & Flatbush Ave
# 171702               3486    Schermerhorn St & Bond St
# 175456                241  DeKalb Ave & S Portland Ave
# ...                   ...                          ...
# 1183146               362           Broadway & W 37 St
# 1186951               151     Cleveland Pl & Spring St
# 1191584               311       Norfolk St & Broome St
# 1200708               297              E 15 St & 3 Ave
# 1201970               379              W 31 St & 7 Ave
#
#          start station latitude  start station longitude  end station id  \
# 26822                 40.694749               -73.983625            2000
# 50614                 40.702551               -73.989402            3414
# 134556                40.680945               -73.975673            3486
# 171702                40.688417               -73.984517             241
# 175456                40.689810               -73.974931             324
# ...                         ...                      ...             ...
# 1183146               40.751726               -73.987535             151
# 1186951               40.722104               -73.997249             311
# 1191584               40.717227               -73.988021             297
# 1200708               40.734232               -73.986923             379
# 1201970               40.749156               -73.991600             496
#
#                     end station name  end station latitude  \
# 26822       Front St & Washington St             40.702551
# 50614       Bergen St & Flatbush Ave             40.680945
# 134556     Schermerhorn St & Bond St             40.688417
# 171702   DeKalb Ave & S Portland Ave             40.689810
# 175456       DeKalb Ave & Hudson Ave             40.689888
# ...                              ...                   ...
# 1183146     Cleveland Pl & Spring St             40.722104
# 1186951       Norfolk St & Broome St             40.717227
# 1191584              E 15 St & 3 Ave             40.734232
# 1200708              W 31 St & 7 Ave             40.749156
# 1201970              E 16 St & 5 Ave             40.737262
#
#          end station longitude  bikeid    usertype  birth year  gender colors  \
# 26822               -73.989402   14530  Subscriber        1987       1  green
# 50614               -73.975673   14530  Subscriber        1992       1  green
# 134556              -73.984517   14530    Customer        1969       0  green
# 171702              -73.974931   14530  Subscriber        1985       1  green
# 175456              -73.981013   14530  Subscriber        1998       1  green
# ...                        ...     ...         ...         ...     ...    ...
# 1183146             -73.997249   14530    Customer        1995       1  green
# 1186951             -73.988021   14530  Subscriber        1973       1  green
# 1191584             -73.986923   14530  Subscriber        1983       1  green
# 1200708             -73.991600   14530  Subscriber        1993       1  green
# 1201970             -73.992390   14530  Subscriber        1981       1  green
#
#                CESIUMcolors capacity  timeAfterStart
# 26822    Cesium.Color.GREEN     None               0
# 50614    Cesium.Color.GREEN     None           31893
# 134556   Cesium.Color.GREEN     None          277310
# 171702   Cesium.Color.GREEN     None          369889
# 175456   Cesium.Color.GREEN     None          373839
# ...                     ...      ...             ...
# 1183146  Cesium.Color.GREEN     None         2451936
# 1186951  Cesium.Color.GREEN     None         2455542
# 1191584  Cesium.Color.GREEN     None         2464023
# 1200708  Cesium.Color.GREEN     None         2502162
# 1201970  Cesium.Color.GREEN     None         2503003
#
# [74 rows x 19 columns]

# %%
# %%time
moved=0
bike141_info_df= bike141_info_df.reset_index(drop=True)
for i in range(len(bike141_info_df)-1):
    if bike141_info_df['end station id'][i] != bike141_info_df['start station id'][i+1] and bike141_info_df['stoptime'][i] <= bike141_info_df['starttime'][i+1]:
        moved+=1
        data = [{'tripduration':28800 ,'starttime':bike141_info_df['stoptime'][i], 'stoptime':bike141_info_df['starttime'][i+1], 'start station id':bike141_info_df['end station id'][i], 'start station name': None, 'start station latitude':bike141_info_df['end station latitude'][i],'start station longitude':bike141_info_df['end station longitude'][i], 'end station id':bike141_info_df['start station id'][i+1], 'end station name':None, 'end station latitude':bike141_info_df['start station latitude'][i+1], 'end station longitude': bike141_info_df['start station longitude'][i+1], 'bikeid':bike141_info_df['bikeid'][i+1],  'usertype':None, 'birth year':None, 'gender':None, 'timeAfterStart':bike141_info_df['tripduration'][i+1], 'colors':'red', 'CESIUMcolors': 'Cesium.Color.RED', 'capacity':None}]
        
        bike141_info_df = bike141_info_df.append(data)
        
print(moved)
#12,000 bikes
# Out:
# 4
# Wall time: 36.1 ms

# %%
assignments2 = vrv.initDataframe('assignments')

# Copy over the static values.
# We'll start by copying a single column, to avoid the size mis-match issue:
assignments2['objectID'] = bike141_info_df['bikeid']
assignments2[['startLat', 'startLon', 'endLat', 'endLon']] = bike141_info_df[['start station latitude', 
                                                                          'start station longitude',
                                                                          'end station latitude',
                                                                          'end station longitude']].values

# Copy our new calculated column:
assignments2['startTimeSec'] = bike141_info_df['timeAfterStart'].values

# Use the calculated column and tripduration to get the end time (in seconds):
assignments2['endTimeSec'] = (bike141_info_df['timeAfterStart'] + bike141_info_df['tripduration']).values
assignments2['cesiumColor'] = bike141_info_df['CESIUMcolors'].values
assignments2['leafletColor'] = bike141_info_df['colors'].values

# Fill in the rest of our assignments df with some hard-coded values:
# (we'll probably want to revisit this later)
assignments2.loc[:,['modelFile', 'modelScale', 'modelMinPxSize', 'startAltMeters', 'endAltMeters', 
                    'leafletWeight', 'leafletStyle', 'leafletOpacity', 'useArrows',
                    'cesiumWeight', 'cesiumStyle', 'cesiumOpacity']] = \
                  ['veroviz/models/UB_Truck.gltf', 100, 45, 0, 0, 
                    2, 'solid', 0.8, False, 
                    2, 'solid', 0.7]

# Finally (for now), let's generate a unique odID value for each row.
# This will make sense only if we assume that each row corresponds to a specific
# O/D pair.  Conversely, if we have turn-by-turn arcs, we'll need to group
# multiple rows into the same O/D pair.  We'll tackle that case if/when 
# we encounter it.
assignments2.loc[:,'odID'] = list(range(0, len(assignments2)))

# %%
vrv.createLeaflet(arcs=assignments2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
vrv.createLeaflet(arcs=assignments2[assignments2['leafletColor'] == 'red'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# startDate: Format is "YYYY-MM-DD"
startDate = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%Y-%m-%d')

# startTime: Format is "HH:MM:SS"
startTime = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%H:%M:%S')

vrv.createCesium(
    assignments = assignments2,
    nodes       = nodes2,
    startDate   = startDate,
    startTime   = startTime,
    cesiumDir   = os.environ['CESIUMDIR'],
    problemDir  = 'IE_670/citibike_example')
# Out:
# Message: File selector was written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/;IE_670;citibike_example.vrv ...
# Message: Configs were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/config.js ...
# Message: Nodes were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/displayNodes.js ...
# Message: Assignments (.js) were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/displayPaths.js ...
# Message: Assignments (.czml) were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/routes.czml ...

# %% [markdown]
# HW 4) ADD IN NEW CITIBIKE MOVES WITHOUT FOR LOOP
# ---

# %%
# %%timeit
bike141_info_df2 = []
#Duplicate the dataframe
value_list=[14530]
bike141_info_df2 = bike_trips_df[bike_trips_df.bikeid.isin(value_list)]
B_bike141_info_df = bike141_info_df2.loc[1:, :].reset_index(drop = True)
B_bike141_info_df[['start station latitude', 'start station longitude']]

#Create new columns in the regular
bike141_info_df2['next start lat'] = 0
bike141_info_df2['next start lon'] = 0
bike141_info_df2['repositioning'] = 0
bike141_info_df2['nextStartTime'] = 0
bike141_info_df2['next start lat'] = B_bike141_info_df['start station latitude']
bike141_info_df2['next start lon'] = B_bike141_info_df['start station longitude']
bike141_info_df2['nextStartTime'] = B_bike141_info_df['timeAfterStart']
#Calculate if repositioning happens
bike141_info_df2.loc[(bike141_info_df2['next start lat'] != bike141_info_df2['end station latitude']), 'repositioning'] = 1
bike141_info_df2.iloc[-1, bike141_info_df2.columns.get_loc('repositioning')] = 0
bike141_info_df2.loc[bike141_info_df2['repositioning'] == 1]
bike141_info_df2
# Out:
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\kayli\Anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# 10.9 ms ± 452 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
repo = pd.DataFrame()
repo = bike141_info_df2[bike141_info_df2['repositioning'] == 1]
repo = repo.reset_index(drop=True)

for i in range(len(repo.index-1)):
    data = [{'tripduration':pd.to_datetime(repo['stoptime'][i]) ,'starttime':repo['stoptime'][i], 'stoptime':repo['nextStartTime'][i], 'start station id':repo['end station id'][i], 'start station name': None, 'start station latitude':repo['end station latitude'][i],'start station longitude':repo['end station longitude'][i], 'end station id':repo['start station id'][i], 'end station name':None, 'end station latitude':repo['start station latitude'][i], 'end station longitude': repo['start station longitude'][i], 'bikeid':repo['bikeid'][i],  'usertype':None, 'birth year':None, 'gender':None, 'timeAfterStart':repo['timeAfterStart'][i] + repo['tripduration'][i] , 'colors':'red', 'CESIUMcolors': 'Cesium.Color.RED', 'capacity':None}]
    bike141_info_df2 = bike141_info_df2.append(data)

# %% [markdown]
# Time Comparision - 10.9 ms without  vs 36.1 ms with a for loop
# ---

# %% [markdown]
# ---
#
# ### Create a Cesium movie for one bike

# %%
# Use this command to get documentation on the `createCesium()` function:
#vrv.createCesium?
bike141_info_df= bike141_info_df.reset_index(drop=True)
bike141_info_df
# Out:
#     tripduration                 starttime                  stoptime  \
# 0            548  2020-01-02 09:25:11.9390  2020-01-02 09:34:20.3600
# 1           1061  2020-01-02 18:16:45.1630  2020-01-02 18:34:26.5780
# 2            400  2020-01-05 14:27:01.9750  2020-01-05 14:33:42.1210
# 3            301  2020-01-06 16:10:01.6600  2020-01-06 16:15:03.0080
# 4            167  2020-01-06 17:15:51.0260  2020-01-06 17:18:38.1240
# ..           ...                       ...                       ...
# 73           529  2020-01-31 08:41:55.1210  2020-01-31 08:50:44.3750
# 74         28800  2020-01-06 21:59:37.9540  2020-01-07 13:23:12.3180
# 75         28800  2020-01-16 09:48:57.9800  2020-01-16 12:00:41.2330
# 76         28800  2020-01-16 12:05:29.6630  2020-01-17 09:15:27.4700
# 77         28800  2020-01-17 17:13:53.6720  2020-01-19 14:50:54.0040
#
#     start station id           start station name  start station latitude  \
# 0                261         Johnson St & Gold St               40.694749
# 1               2000     Front St & Washington St               40.702551
# 2               3414     Bergen St & Flatbush Ave               40.680945
# 3               3486    Schermerhorn St & Bond St               40.688417
# 4                241  DeKalb Ave & S Portland Ave               40.689810
# ..               ...                          ...                     ...
# 73               379              W 31 St & 7 Ave               40.749156
# 74              3232                         None               40.689622
# 75               280                         None               40.733320
# 76              3812                         None               40.734814
# 77               509                         None               40.745497
#
#     start station longitude  end station id             end station name  \
# 0                -73.983625            2000     Front St & Washington St
# 1                -73.989402            3414     Bergen St & Flatbush Ave
# 2                -73.975673            3486    Schermerhorn St & Bond St
# 3                -73.984517             241  DeKalb Ave & S Portland Ave
# 4                -73.974931             324      DeKalb Ave & Hudson Ave
# ..                      ...             ...                          ...
# 73               -73.991600             496              E 16 St & 5 Ave
# 74               -73.983043            3377                         None
# 75               -73.995101             326                         None
# 76               -73.992085             504                         None
# 77               -74.001971            3724                         None
#
#     end station latitude  end station longitude  bikeid    usertype  \
# 0              40.702551             -73.989402   14530  Subscriber
# 1              40.680945             -73.975673   14530  Subscriber
# 2              40.688417             -73.984517   14530    Customer
# 3              40.689810             -73.974931   14530  Subscriber
# 4              40.689888             -73.981013   14530  Subscriber
# ..                   ...                    ...     ...         ...
# 73             40.737262             -73.992390   14530  Subscriber
# 74             40.678612             -73.990373   14530        None
# 75             40.729538             -73.984267   14530        None
# 76             40.732219             -73.981656   14530        None
# 77             40.766741             -73.979069   14530        None
#
#    birth year gender colors        CESIUMcolors capacity  timeAfterStart
# 0        1987      1  green  Cesium.Color.GREEN     None               0
# 1        1992      1  green  Cesium.Color.GREEN     None           31893
# 2        1969      0  green  Cesium.Color.GREEN     None          277310
# 3        1985      1  green  Cesium.Color.GREEN     None          369889
# 4        1998      1  green  Cesium.Color.GREEN     None          373839
# ..        ...    ...    ...                 ...      ...             ...
# 73       1981      1  green  Cesium.Color.GREEN     None         2503003
# 74       None   None    red    Cesium.Color.RED     None             370
# 75       None   None    red    Cesium.Color.RED     None             288
# 76       None   None    red    Cesium.Color.RED     None             377
# 77       None   None    red    Cesium.Color.RED     None             322
#
# [78 rows x 19 columns]

# %% [markdown]
# HW 5) ADD STATIC ASSIGNMENTS TO THE DATABASE
# ---

# %%
bike141_static_info_df = pd.DataFrame(columns= ['tripduration','starttime', 'stoptime', 'start station id', 'start station name', 'start station latitude','start station longitude', 'end station id', 'end station name', 'end station latitude', 'end station longitude','bikeid','usertype','birth year','gender', 'timeAfterStart','colors','CESIUMcolors','Cesium.Color.RED','capacity'])
data=[]

for i in range(len(bike141_info_df.index)-1):
    data = [{'tripduration':0,'starttime':bike141_info_df['stoptime'][i], 'stoptime':bike141_info_df['starttime'][i+1], 'start station id':bike141_info_df['end station id'][i], 'start station name': None, 'start station latitude':bike141_info_df['end station latitude'][i],'start station longitude':bike141_info_df['end station longitude'][i], 'end station id':bike141_info_df['start station id'][i+1], 'end station name':None, 'end station latitude':bike141_info_df['start station latitude'][i+1], 'end station longitude': bike141_info_df['start station longitude'][i+1], 'bikeid':bike141_info_df['bikeid'][i+1],  'usertype':None, 'birth year':None, 'gender':None, 'timeAfterStart':0, 'colors':'red', 'CESIUMcolors': 'Cesium.Color.RED', 'capacity':None}]
    bike141_static_info_df = bike141_static_info_df.append(data)
    
bike141_static_info_df= bike141_static_info_df.reset_index(drop=True)
bike141_static_info_df
# Out:
#    tripduration                 starttime                  stoptime  \
# 0             0  2020-01-02 09:34:20.3600  2020-01-02 18:16:45.1630
# 1             0  2020-01-02 18:34:26.5780  2020-01-05 14:27:01.9750
# 2             0  2020-01-05 14:33:42.1210  2020-01-06 16:10:01.6600
# 3             0  2020-01-06 16:15:03.0080  2020-01-06 17:15:51.0260
# 4             0  2020-01-06 17:18:38.1240  2020-01-06 17:24:58.6320
# ..          ...                       ...                       ...
# 72            0  2020-01-31 08:36:30.1120  2020-01-31 08:41:55.1210
# 73            0  2020-01-31 08:50:44.3750  2020-01-06 21:59:37.9540
# 74            0  2020-01-07 13:23:12.3180  2020-01-16 09:48:57.9800
# 75            0  2020-01-16 12:00:41.2330  2020-01-16 12:05:29.6630
# 76            0  2020-01-17 09:15:27.4700  2020-01-17 17:13:53.6720
#
#    start station id start station name  start station latitude  \
# 0              2000               None               40.702551
# 1              3414               None               40.680945
# 2              3486               None               40.688417
# 3               241               None               40.689810
# 4               324               None               40.689888
# ..              ...                ...                     ...
# 72              379               None               40.749156
# 73              496               None               40.737262
# 74             3377               None               40.678612
# 75              326               None               40.729538
# 76              504               None               40.732219
#
#     start station longitude end station id end station name  \
# 0                -73.989402           2000             None
# 1                -73.975673           3414             None
# 2                -73.984517           3486             None
# 3                -73.974931            241             None
# 4                -73.981013            324             None
# ..                      ...            ...              ...
# 72               -73.991600            379             None
# 73               -73.992390           3232             None
# 74               -73.990373            280             None
# 75               -73.984267           3812             None
# 76               -73.981656            509             None
#
#     end station latitude  end station longitude bikeid usertype birth year  \
# 0              40.702551             -73.989402  14530     None       None
# 1              40.680945             -73.975673  14530     None       None
# 2              40.688417             -73.984517  14530     None       None
# 3              40.689810             -73.974931  14530     None       None
# 4              40.689888             -73.981013  14530     None       None
# ..                   ...                    ...    ...      ...        ...
# 72             40.749156             -73.991600  14530     None       None
# 73             40.689622             -73.983043  14530     None       None
# 74             40.733320             -73.995101  14530     None       None
# 75             40.734814             -73.992085  14530     None       None
# 76             40.745497             -74.001971  14530     None       None
#
#    gender timeAfterStart colors      CESIUMcolors  Cesium.Color.RED capacity
# 0    None              0    red  Cesium.Color.RED               NaN     None
# 1    None              0    red  Cesium.Color.RED               NaN     None
# 2    None              0    red  Cesium.Color.RED               NaN     None
# 3    None              0    red  Cesium.Color.RED               NaN     None
# 4    None              0    red  Cesium.Color.RED               NaN     None
# ..    ...            ...    ...               ...               ...      ...
# 72   None              0    red  Cesium.Color.RED               NaN     None
# 73   None              0    red  Cesium.Color.RED               NaN     None
# 74   None              0    red  Cesium.Color.RED               NaN     None
# 75   None              0    red  Cesium.Color.RED               NaN     None
# 76   None              0    red  Cesium.Color.RED               NaN     None
#
# [77 rows x 20 columns]

# %%
bike141_static_info_df['timeAfterStart'] = pd.to_datetime(bike141_static_info_df['starttime']) - \
                                  pd.to_datetime(min(bike141_static_info_df['starttime']))

# Now, convert this to a decimal number of seconds:
bike141_static_info_df['timeAfterStart'] = bike141_static_info_df['timeAfterStart'].dt.total_seconds().astype(int)

bike141_static_info_df['tripduration'] = pd.to_datetime(bike141_static_info_df['stoptime']) - \
                                  pd.to_datetime(bike141_static_info_df['starttime'])
bike141_static_info_df['tripduration'] = bike141_static_info_df['tripduration'].dt.total_seconds().astype(int)

bike141_static_info_df
# Out:
#     tripduration                 starttime                  stoptime  \
# 0          31344  2020-01-02 09:34:20.3600  2020-01-02 18:16:45.1630
# 1         244355  2020-01-02 18:34:26.5780  2020-01-05 14:27:01.9750
# 2          92179  2020-01-05 14:33:42.1210  2020-01-06 16:10:01.6600
# 3           3648  2020-01-06 16:15:03.0080  2020-01-06 17:15:51.0260
# 4            380  2020-01-06 17:18:38.1240  2020-01-06 17:24:58.6320
# ..           ...                       ...                       ...
# 72           325  2020-01-31 08:36:30.1120  2020-01-31 08:41:55.1210
# 73      -2112666  2020-01-31 08:50:44.3750  2020-01-06 21:59:37.9540
# 74        764745  2020-01-07 13:23:12.3180  2020-01-16 09:48:57.9800
# 75           288  2020-01-16 12:00:41.2330  2020-01-16 12:05:29.6630
# 76         28706  2020-01-17 09:15:27.4700  2020-01-17 17:13:53.6720
#
#    start station id start station name  start station latitude  \
# 0              2000               None               40.702551
# 1              3414               None               40.680945
# 2              3486               None               40.688417
# 3               241               None               40.689810
# 4               324               None               40.689888
# ..              ...                ...                     ...
# 72              379               None               40.749156
# 73              496               None               40.737262
# 74             3377               None               40.678612
# 75              326               None               40.729538
# 76              504               None               40.732219
#
#     start station longitude end station id end station name  \
# 0                -73.989402           2000             None
# 1                -73.975673           3414             None
# 2                -73.984517           3486             None
# 3                -73.974931            241             None
# 4                -73.981013            324             None
# ..                      ...            ...              ...
# 72               -73.991600            379             None
# 73               -73.992390           3232             None
# 74               -73.990373            280             None
# 75               -73.984267           3812             None
# 76               -73.981656            509             None
#
#     end station latitude  end station longitude bikeid usertype birth year  \
# 0              40.702551             -73.989402  14530     None       None
# 1              40.680945             -73.975673  14530     None       None
# 2              40.688417             -73.984517  14530     None       None
# 3              40.689810             -73.974931  14530     None       None
# 4              40.689888             -73.981013  14530     None       None
# ..                   ...                    ...    ...      ...        ...
# 72             40.749156             -73.991600  14530     None       None
# 73             40.689622             -73.983043  14530     None       None
# 74             40.733320             -73.995101  14530     None       None
# 75             40.734814             -73.992085  14530     None       None
# 76             40.745497             -74.001971  14530     None       None
#
#    gender  timeAfterStart colors      CESIUMcolors  Cesium.Color.RED capacity
# 0    None               0    red  Cesium.Color.RED               NaN     None
# 1    None           32406    red  Cesium.Color.RED               NaN     None
# 2    None          277161    red  Cesium.Color.RED               NaN     None
# 3    None          369642    red  Cesium.Color.RED               NaN     None
# 4    None          373457    red  Cesium.Color.RED               NaN     None
# ..    ...             ...    ...               ...               ...      ...
# 72   None         2502129    red  Cesium.Color.RED               NaN     None
# 73   None         2502984    red  Cesium.Color.RED               NaN     None
# 74   None          445731    red  Cesium.Color.RED               NaN     None
# 75   None         1218380    red  Cesium.Color.RED               NaN     None
# 76   None         1294867    red  Cesium.Color.RED               NaN     None
#
# [77 rows x 20 columns]

# %%
bike141_static_info_df=bike141_static_info_df.drop(bike141_static_info_df.index[73])
bike141_static_info_df
# Out:
#     tripduration                 starttime                  stoptime  \
# 0          31344  2020-01-02 09:34:20.3600  2020-01-02 18:16:45.1630
# 1         244355  2020-01-02 18:34:26.5780  2020-01-05 14:27:01.9750
# 2          92179  2020-01-05 14:33:42.1210  2020-01-06 16:10:01.6600
# 3           3648  2020-01-06 16:15:03.0080  2020-01-06 17:15:51.0260
# 4            380  2020-01-06 17:18:38.1240  2020-01-06 17:24:58.6320
# ..           ...                       ...                       ...
# 71         37254  2020-01-30 22:07:00.2830  2020-01-31 08:27:54.4500
# 72           325  2020-01-31 08:36:30.1120  2020-01-31 08:41:55.1210
# 74        764745  2020-01-07 13:23:12.3180  2020-01-16 09:48:57.9800
# 75           288  2020-01-16 12:00:41.2330  2020-01-16 12:05:29.6630
# 76         28706  2020-01-17 09:15:27.4700  2020-01-17 17:13:53.6720
#
#    start station id start station name  start station latitude  \
# 0              2000               None               40.702551
# 1              3414               None               40.680945
# 2              3486               None               40.688417
# 3               241               None               40.689810
# 4               324               None               40.689888
# ..              ...                ...                     ...
# 71              297               None               40.734232
# 72              379               None               40.749156
# 74             3377               None               40.678612
# 75              326               None               40.729538
# 76              504               None               40.732219
#
#     start station longitude end station id end station name  \
# 0                -73.989402           2000             None
# 1                -73.975673           3414             None
# 2                -73.984517           3486             None
# 3                -73.974931            241             None
# 4                -73.981013            324             None
# ..                      ...            ...              ...
# 71               -73.986923            297             None
# 72               -73.991600            379             None
# 74               -73.990373            280             None
# 75               -73.984267           3812             None
# 76               -73.981656            509             None
#
#     end station latitude  end station longitude bikeid usertype birth year  \
# 0              40.702551             -73.989402  14530     None       None
# 1              40.680945             -73.975673  14530     None       None
# 2              40.688417             -73.984517  14530     None       None
# 3              40.689810             -73.974931  14530     None       None
# 4              40.689888             -73.981013  14530     None       None
# ..                   ...                    ...    ...      ...        ...
# 71             40.734232             -73.986923  14530     None       None
# 72             40.749156             -73.991600  14530     None       None
# 74             40.733320             -73.995101  14530     None       None
# 75             40.734814             -73.992085  14530     None       None
# 76             40.745497             -74.001971  14530     None       None
#
#    gender  timeAfterStart colors      CESIUMcolors  Cesium.Color.RED capacity
# 0    None               0    red  Cesium.Color.RED               NaN     None
# 1    None           32406    red  Cesium.Color.RED               NaN     None
# 2    None          277161    red  Cesium.Color.RED               NaN     None
# 3    None          369642    red  Cesium.Color.RED               NaN     None
# 4    None          373457    red  Cesium.Color.RED               NaN     None
# ..    ...             ...    ...               ...               ...      ...
# 71   None         2464359    red  Cesium.Color.RED               NaN     None
# 72   None         2502129    red  Cesium.Color.RED               NaN     None
# 74   None          445731    red  Cesium.Color.RED               NaN     None
# 75   None         1218380    red  Cesium.Color.RED               NaN     None
# 76   None         1294867    red  Cesium.Color.RED               NaN     None
#
# [76 rows x 20 columns]

# %%
bike141_static_info_df= bike141_static_info_df.reset_index(drop=True)
bike141_static_info_df
# Out:
#     tripduration                 starttime                  stoptime  \
# 0          31344  2020-01-02 09:34:20.3600  2020-01-02 18:16:45.1630
# 1         244355  2020-01-02 18:34:26.5780  2020-01-05 14:27:01.9750
# 2          92179  2020-01-05 14:33:42.1210  2020-01-06 16:10:01.6600
# 3           3648  2020-01-06 16:15:03.0080  2020-01-06 17:15:51.0260
# 4            380  2020-01-06 17:18:38.1240  2020-01-06 17:24:58.6320
# ..           ...                       ...                       ...
# 71         37254  2020-01-30 22:07:00.2830  2020-01-31 08:27:54.4500
# 72           325  2020-01-31 08:36:30.1120  2020-01-31 08:41:55.1210
# 73        764745  2020-01-07 13:23:12.3180  2020-01-16 09:48:57.9800
# 74           288  2020-01-16 12:00:41.2330  2020-01-16 12:05:29.6630
# 75         28706  2020-01-17 09:15:27.4700  2020-01-17 17:13:53.6720
#
#    start station id start station name  start station latitude  \
# 0              2000               None               40.702551
# 1              3414               None               40.680945
# 2              3486               None               40.688417
# 3               241               None               40.689810
# 4               324               None               40.689888
# ..              ...                ...                     ...
# 71              297               None               40.734232
# 72              379               None               40.749156
# 73             3377               None               40.678612
# 74              326               None               40.729538
# 75              504               None               40.732219
#
#     start station longitude end station id end station name  \
# 0                -73.989402           2000             None
# 1                -73.975673           3414             None
# 2                -73.984517           3486             None
# 3                -73.974931            241             None
# 4                -73.981013            324             None
# ..                      ...            ...              ...
# 71               -73.986923            297             None
# 72               -73.991600            379             None
# 73               -73.990373            280             None
# 74               -73.984267           3812             None
# 75               -73.981656            509             None
#
#     end station latitude  end station longitude bikeid usertype birth year  \
# 0              40.702551             -73.989402  14530     None       None
# 1              40.680945             -73.975673  14530     None       None
# 2              40.688417             -73.984517  14530     None       None
# 3              40.689810             -73.974931  14530     None       None
# 4              40.689888             -73.981013  14530     None       None
# ..                   ...                    ...    ...      ...        ...
# 71             40.734232             -73.986923  14530     None       None
# 72             40.749156             -73.991600  14530     None       None
# 73             40.733320             -73.995101  14530     None       None
# 74             40.734814             -73.992085  14530     None       None
# 75             40.745497             -74.001971  14530     None       None
#
#    gender  timeAfterStart colors      CESIUMcolors  Cesium.Color.RED capacity
# 0    None               0    red  Cesium.Color.RED               NaN     None
# 1    None           32406    red  Cesium.Color.RED               NaN     None
# 2    None          277161    red  Cesium.Color.RED               NaN     None
# 3    None          369642    red  Cesium.Color.RED               NaN     None
# 4    None          373457    red  Cesium.Color.RED               NaN     None
# ..    ...             ...    ...               ...               ...      ...
# 71   None         2464359    red  Cesium.Color.RED               NaN     None
# 72   None         2502129    red  Cesium.Color.RED               NaN     None
# 73   None          445731    red  Cesium.Color.RED               NaN     None
# 74   None         1218380    red  Cesium.Color.RED               NaN     None
# 75   None         1294867    red  Cesium.Color.RED               NaN     None
#
# [76 rows x 20 columns]

# %%
assignmentsS = vrv.initDataframe('assignments')
for i in range(len(bike141_static_info_df)):
    assignmentsS = vrv.addStaticAssignment(
        initAssignments = assignmentsS, 
        odID            = i+77, 
        objectID        = 'bike',
        modelFile       = 'veroviz/models/UB_Truck.gltf', 
        modelScale      = 100, 
        modelMinPxSize  = 45, 
        loc             = [bike141_static_info_df['start station latitude'][i] , bike141_static_info_df['start station longitude'][i], 0],
        startTimeSec    = bike141_static_info_df['timeAfterStart'][i],
        endTimeSec      = bike141_static_info_df['timeAfterStart'][i] + bike141_static_info_df['tripduration'][i])

# %%
assignments2=assignments2.append(assignmentsS)
assignments2
# Out:
#    odID objectID                          modelFile modelScale modelMinPxSize  \
# 0     0    14530  /////veroviz/models/UB_Truck.gltf        100             45
# 1     1    14530      /veroviz/models/UB_Truck.gltf        100             45
# 2     2    14530      /veroviz/models/UB_Truck.gltf        100             45
# 3     3    14530      /veroviz/models/UB_Truck.gltf        100             45
# 4     4    14530      /veroviz/models/UB_Truck.gltf        100             45
# ..  ...      ...                                ...        ...            ...
# 71  148     bike      /veroviz/models/UB_Truck.gltf        100             45
# 72  149     bike      /veroviz/models/UB_Truck.gltf        100             45
# 73  150     bike      /veroviz/models/UB_Truck.gltf        100             45
# 74  151     bike      /veroviz/models/UB_Truck.gltf        100             45
# 75  152     bike       veroviz/models/UB_Truck.gltf        100             45
#
#    startTimeSec   startLat   startLon startAltMeters endTimeSec  ...  \
# 0             0  40.694749 -73.983625              0        548  ...
# 1         31893  40.702551 -73.989402              0      32954  ...
# 2        277310  40.680945 -73.975673              0     277710  ...
# 3        369889  40.688417 -73.984517              0     370190  ...
# 4        373839  40.689810 -73.974931              0     374006  ...
# ..          ...        ...        ...            ...        ...  ...
# 71      2464359  40.734232 -73.986923              0    2501613  ...
# 72      2502129  40.749156 -73.991600              0    2502454  ...
# 73       445731  40.678612 -73.990373              0    1210476  ...
# 74      1218380  40.729538 -73.984267              0    1218668  ...
# 75      1294867  40.732219 -73.981656              0    1323573  ...
#
#     endAltMeters  leafletColor leafletWeight leafletStyle leafletOpacity  \
# 0              0         green             2        solid            0.8
# 1              0         green             2        solid            0.8
# 2              0         green             2        solid            0.8
# 3              0         green             2        solid            0.8
# 4              0         green             2        solid            0.8
# ..           ...           ...           ...          ...            ...
# 71             0          None          None         None           None
# 72             0          None          None         None           None
# 73             0          None          None         None           None
# 74             0          None          None         None           None
# 75             0          None          None         None           None
#
#    useArrows         cesiumColor cesiumWeight cesiumStyle cesiumOpacity
# 0      False  Cesium.Color.GREEN            2       solid           0.7
# 1      False  Cesium.Color.GREEN            2       solid           0.7
# 2      False  Cesium.Color.GREEN            2       solid           0.7
# 3      False  Cesium.Color.GREEN            2       solid           0.7
# 4      False  Cesium.Color.GREEN            2       solid           0.7
# ..       ...                 ...          ...         ...           ...
# 71      None                None         None        None          None
# 72      None                None         None        None          None
# 73      None                None         None        None          None
# 74      None                None         None        None          None
# 75      None                None         None        None          None
#
# [154 rows x 22 columns]

# %%
# this works but some datapoints put two cars overlapped on a handful of occations
# startDate: Format is "YYYY-MM-DD"
startDate = pd.to_datetime(min(bike141_info_df['starttime'])).strftime('%Y-%m-%d')

# startTime: Format is "HH:MM:SS"
startTime = pd.to_datetime(min(bike141_info_df['starttime'])).strftime('%H:%M:%S')

vrv.createCesium(
    assignments = assignments2,
    nodes       = nodes2,
    startDate   = startDate,
    startTime   = startTime,
    cesiumDir   = os.environ['CESIUMDIR'],
    problemDir  = 'IE_670/citibike_example')
# Out:
# Message: File selector was written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/;IE_670;citibike_example.vrv ...
# Message: Configs were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/config.js ...
# Message: Nodes were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/displayNodes.js ...
# Message: Assignments (.js) were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/displayPaths.js ...
# Message: Assignments (.czml) were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/routes.czml ...

# %% [markdown]
# ---
#
# #### Playing around with dates/times
# - Here's some code related to formatting dates/times.  There might be something useful here in the future...

# %%
pd.to_datetime(bike_trips_df['starttime']).dt.date
# Out:
# 0          2020-01-01
# 1          2020-01-01
# 2          2020-01-01
# 3          2020-01-01
# 4          2020-01-01
#               ...
# 1240591    2020-01-31
# 1240592    2020-01-31
# 1240593    2020-01-31
# 1240594    2020-01-31
# 1240595    2020-01-31
# Name: starttime, Length: 1240596, dtype: object

# %%
pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%Y-%m-%d')
# Out:
# '2020-01-01'

# %%
pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%H:%M:%S')
# Out:
# '00:00:55'

# %% [markdown]
# ---
#
# ### NYC Subway Stations
#
# - A list of subway stations may be found here:
#     - http://web.mta.info/developers/data/nyct/subway/Stations.csv
#
# - Other links:
#     - http://web.mta.info/developers/index.html
#     - http://datamine.mta.info/list-of-feeds
#
# Ideas:
# - For a given location, find the nearest subway station.
# - For a given destination, find the nearest **available** CitiBike station.
# - For a given O/D pair, determine the best combination of subways/bikes to use.

# %%
trains_df = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/Stations.csv')
trains_df.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#                 Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria - Ditmars Blvd       Q            N W  Elevated      40.775036
# 1            Astoria Blvd       Q            N W  Elevated      40.770258
# 2                   30 Av       Q            N W  Elevated      40.766779
# 3                Broadway       Q            N W  Elevated      40.761820
# 4                   36 Av       Q            N W  Elevated      40.756804
#
#    GTFS Longitude   North Direction Label South Direction Label
# 0      -73.912034                     NaN             Manhattan
# 1      -73.917843            Ditmars Blvd             Manhattan
# 2      -73.921479  Astoria - Ditmars Blvd             Manhattan
# 3      -73.925508  Astoria - Ditmars Blvd             Manhattan
# 4      -73.929575  Astoria - Ditmars Blvd             Manhattan

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
trainNodes = vrv.initDataframe('nodes')

# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied 
#       just a single column first.  
trainNodes['id'] = trains_df['Station ID'].values
trainNodes[['id', 'lat', 'lon', 'nodeName']] = trains_df[['Station ID', 'GTFS Latitude', 'GTFS Longitude', 'Stop Name']].values
trainNodes[['leafletIconText', 'cesiumIconText']] = trains_df[['Stop Name', 'Station ID']].values

# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
trainNodes.loc[:,'altMeters'] = 0
trainNodes.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType', 'leafletColor']] = [
             'CitiBikeStation',  'fa',                'train',         'blue']
trainNodes.loc[:,['cesiumIconType', 'cesiumColor']] = ['pin', 'Cesium.Color.BLUE']

# %%
vrv.createLeaflet(nodes=trainNodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import cos, asin, sqrt
station_info_df['lat'] = station_info_df['lat'].astype(float)
station_info_df['lon'] = station_info_df['lon'].astype(float)
bikes = pd.DataFrame(station_info_df[['lat', 'lon']])
trains=pd.DataFrame(trains_df[['GTFS Latitude', 'GTFS Longitude']])


def distance(lat1, lon1, lat2, lon2):
    p = 0.017453292519943295
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p)*cos(lat2*p) * (1-cos((lon2-lon1)*p)) / 2
    return 12742 * asin(sqrt(a))

def closest(data, v):
    return min(data, key=lambda p: distance(v['lat'],v['lon'],p['lat'],p['lon']))

# %%
from math import radians, cos, sin, asin, sqrt

def stationClose(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

center_point = [{'lat': -7.7940023, 'lng': 110.3656535}]
test_point = [{'lat': -7.79457, 'lng': 110.36563}]

lat1 = center_point[0]['lat']
lon1 = center_point[0]['lng']
lat2 = test_point[0]['lat']
lon2 = test_point[0]['lng']

radius = 1.00 # in kilometer

a = haversine(lon1, lat1, lon2, lat2)

#print('Distance (km) : ', a)
#if a <= radius:
#    return 1
#else:
#    return 0

# %%
closeStations=0
bikes = pd.DataFrame(station_info_df[['lat', 'lon']])
trains=pd.DataFrame(trains_df[['GTFS Latitude', 'GTFS Longitude']])
locations=[]
nodesB = pd.DataFrame()



for i in range(len(bikes)):
    for j in range(len(trains)):
        if stationClose(bikes['lon'].iloc[i],bikes['lat'].iloc[i],trains['GTFS Longitude'].iloc[j],trains['GTFS Latitude'].iloc[j])<= 1:
                closeStations+=1
           # nodesB = pd.DataFrame( bikes['lat'].iloc[i].values)
            #df = pd.DataFrame()
           # nodesB.append(df)

print(closeStations)

#457141
# Out:
# 6619

# %%
dataSet = pd.DataFrame(columns= ['tripduration','starttime', 'stoptime', 'start station id', 'start station name', 'start station latitude','start station longitude', 'end station id', 'end station name', 'end station latitude', 'end station longitude','bikeid','usertype','birth year','gender', 'timeAfterStart','colors','CESIUMcolors','Cesium.Color.RED','capacity'])
dataSet1 = bike141_info_df.loc[[1,2] , :]
dataSet=dataSet.append(dataSet1)
dataSet2 = bike141_info_df.loc[[3,4] , :]
dataSet = dataSet.append(dataSet2)
dataSet3 = bike141_static_info_df.loc[[1,2] , :]
dataSet = dataSet.append(dataSet3)
dataSet4 = bike141_static_info_df.loc[[3,4] , :]
dataSet = dataSet.append(dataSet4)
# dataSet.append(dataSet4)
dataSet
# Out:
#          CESIUMcolors Cesium.Color.RED bikeid birth year capacity colors  \
# 1  Cesium.Color.GREEN              NaN  14530       1992     None  green
# 2  Cesium.Color.GREEN              NaN  14530       1969     None  green
# 3  Cesium.Color.GREEN              NaN  14530       1985     None  green
# 4  Cesium.Color.GREEN              NaN  14530       1998     None  green
# 1    Cesium.Color.RED              NaN  14530       None     None    red
# 2    Cesium.Color.RED              NaN  14530       None     None    red
# 3    Cesium.Color.RED              NaN  14530       None     None    red
# 4    Cesium.Color.RED              NaN  14530       None     None    red
#
#   end station id  end station latitude  end station longitude  \
# 1           3414             40.680945             -73.975673
# 2           3486             40.688417             -73.984517
# 3            241             40.689810             -73.974931
# 4            324             40.689888             -73.981013
# 1           3414             40.680945             -73.975673
# 2           3486             40.688417             -73.984517
# 3            241             40.689810             -73.974931
# 4            324             40.689888             -73.981013
#
#               end station name gender start station id  \
# 1     Bergen St & Flatbush Ave      1             2000
# 2    Schermerhorn St & Bond St      0             3414
# 3  DeKalb Ave & S Portland Ave      1             3486
# 4      DeKalb Ave & Hudson Ave      1              241
# 1                         None   None             3414
# 2                         None   None             3486
# 3                         None   None              241
# 4                         None   None              324
#
#    start station latitude  start station longitude  \
# 1               40.702551               -73.989402
# 2               40.680945               -73.975673
# 3               40.688417               -73.984517
# 4               40.689810               -73.974931
# 1               40.680945               -73.975673
# 2               40.688417               -73.984517
# 3               40.689810               -73.974931
# 4               40.689888               -73.981013
#
#             start station name                 starttime  \
# 1     Front St & Washington St  2020-01-02 18:16:45.1630
# 2     Bergen St & Flatbush Ave  2020-01-05 14:27:01.9750
# 3    Schermerhorn St & Bond St  2020-01-06 16:10:01.6600
# 4  DeKalb Ave & S Portland Ave  2020-01-06 17:15:51.0260
# 1                         None  2020-01-02 18:34:26.5780
# 2                         None  2020-01-05 14:33:42.1210
# 3                         None  2020-01-06 16:15:03.0080
# 4                         None  2020-01-06 17:18:38.1240
#
#                    stoptime timeAfterStart tripduration    usertype
# 1  2020-01-02 18:34:26.5780          31893         1061  Subscriber
# 2  2020-01-05 14:33:42.1210         277310          400    Customer
# 3  2020-01-06 16:15:03.0080         369889          301  Subscriber
# 4  2020-01-06 17:18:38.1240         373839          167  Subscriber
# 1  2020-01-05 14:27:01.9750         153211       244355        None
# 2  2020-01-06 16:10:01.6600         397966        92179        None
# 3  2020-01-06 17:15:51.0260         490447         3648        None
# 4  2020-01-06 17:24:58.6320         494262          380        None

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodesTest = vrv.initDataframe('nodes')
# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied
#       just a single column first.
nodesTest['id'] = dataSet['start station id'].values
nodesTest[['lat', 'lon', 'nodeName']] = dataSet[[ 'start station latitude', 'start station longitude', 'start station name']].values
nodesTest[['leafletIconText', 'cesiumIconText']] = dataSet[[ 'start station name', 'start station id']].values
# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodesTest['leafletColor'] = station_status_df['colors']
nodesTest['cesiumColor'] = station_status_df['CESIUMcolors']
nodesTest.loc[:,'altMeters'] = 0
nodesTest.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType']] = [
             'Citibike Station', 'fa', 'bicycle']
nodes2.loc[:,'cesiumIconType'] = 'pin'

# %%
assignmentsTest = vrv.initDataframe('assignments')

# Copy over the static values.
# We'll start by copying a single column, to avoid the size mis-match issue:
assignmentsTest['objectID'] = dataSet['bikeid']
assignmentsTest[['startLat', 'startLon', 'endLat', 'endLon']] = dataSet[['start station latitude', 
                                                                          'start station longitude',
                                                                          'end station latitude',
                                                                          'end station longitude']].values

# Copy our new calculated column:
assignmentsTest['startTimeSec'] = dataSet['timeAfterStart'].values

# Use the calculated column and tripduration to get the end time (in seconds):
assignmentsTest['endTimeSec'] = (dataSet['timeAfterStart'] + dataSet['tripduration']).values
assignmentsTest['cesiumColor'] = dataSet['CESIUMcolors'].values
assignmentsTest['leafletColor'] = dataSet['colors'].values

# Fill in the rest of our assignments df with some hard-coded values:
# (we'll probably want to revisit this later)
assignmentsTest.loc[:,['modelFile', 'modelScale', 'modelMinPxSize', 'startAltMeters', 'endAltMeters', 
                    'leafletWeight', 'leafletStyle', 'leafletOpacity', 'useArrows',
                    'cesiumWeight', 'cesiumStyle', 'cesiumOpacity']] = \
                  ['veroviz/models/UB_Truck.gltf', 100, 45, 0, 0, 
                    2, 'solid', 0.8, False, 
                    2, 'solid', 0.7]

# Finally (for now), let's generate a unique odID value for each row.
# This will make sense only if we assume that each row corresponds to a specific
# O/D pair.  Conversely, if we have turn-by-turn arcs, we'll need to group
# multiple rows into the same O/D pair.  We'll tackle that case if/when 
# we encounter it.
assignmentsTest.loc[:,'odID'] = list(range(0, len(assignmentsTest)))

# %%
# startDate: Format is "YYYY-MM-DD"
startDate = pd.to_datetime(min(dataSet['starttime'])).strftime('%Y-%m-%d')

# startTime: Format is "HH:MM:SS"
startTime = pd.to_datetime(min(dataSet['starttime'])).strftime('%H:%M:%S')

vrv.createCesium(
    assignments = assignmentsTest,
    nodes       = nodesTest,
    startDate   = startDate,
    startTime   = startTime,
    cesiumDir   = os.environ['CESIUMDIR'],
    problemDir  = 'IE_670/citibike_example')
# Out:
# Message: File selector was written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/;IE_670;citibike_example.vrv ...
# Message: Configs were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/config.js ...
# Message: Nodes were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/displayNodes.js ...
# Message: Assignments (.js) were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/displayPaths.js ...
# Message: Assignments (.czml) were written to C:/Users/kayli/Downloads/Cesium-1.63/IE_670/citibike_example/routes.czml ...
